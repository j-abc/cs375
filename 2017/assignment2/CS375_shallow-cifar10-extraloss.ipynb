# %% [markdown]
# # CS375 Assignment 2 Lab Report
# #### Group 6

# %% [markdown]
# ## Part 1: Task Generalization

# %%
# %matplotlib inline 
import os
import numpy as np
import tensorflow as tf
import pymongo as pm
import gridfs
import cPickle
import scipy.signal as signal
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook, trange
from assignment_utils import *

# %%
import pandas as pd

# %%
model_df = pd.read_csv('models.csv',delimiter = ' ')

# %%
model_df
# Out:
#        model_name data_name         loss_name exp_id test_id
# 0  shallow_bottle   cifar10  autoencoder_loss    end     end
# 1  shallow_bottle   cifar10     ae_conv1_loss    end     end
# 2  pooled_shallow   cifar10  autoencoder_loss    end     end
# 3  pooled_shallow   cifar10     ae_conv1_loss    end     end
# 4    bottle_model   cifar10  autoencoder_loss    end     end
# 5    bottle_model   cifar10     ae_conv3_loss    end     end

# %% [markdown]
# ### Getting data from the database

# %%
from model_switcher import *

# %%
my_model_shallow = model_switcher(model_name = 'shallow_bottle',
                          data_name = 'cifar10',
                          loss_name = 'ae_conv1_loss')

# %%
vars(my_model_shallow)
# Out:
# {'collname': 'shallow_bottle_ae_conv1_loss',
#  'data_name': 'cifar10',
#  'dbname': 'cifar10',
#  'exp_fn': <class experiments.cifar10 at 0x7f95865f72c0>,
#  'exp_id': '',
#  'layers': ['conv1', 'deconv1'],
#  'loss_fn': <function losses.ae_conv1_loss>,
#  'loss_name': 'ae_conv1_loss',
#  'model_fn': <function models.shallow_bottle>,
#  'model_name': 'shallow_bottle',
#  'test_id': ''}

# %%
coll, db = p_get_coll(vars(my_model_shallow)['collname'], vars(my_model_shallow)['dbname'])
print(coll)
print coll.distinct('exp_id')
# Out:
# Collection(Database(MongoClient(host=['localhost:24444'], document_class=dict, tz_aware=False, connect=True), u'cifar10'), u'shallow_bottle_ae_conv1_loss.files')
# [u'ha12', u'ha12_2000_V6', u'end', u'end_test']

# %% [markdown]
# ### Plotting the training curve
# To see the training curve for the experiment, we pull the training loss and plot it, along with a smoothed version of the training loss obtained by convolving the loss with a boxcar.

# %%
train_id = 'end'
test_id = train_id + '_test'

print(train_id)
p22_training(train_id,coll)
# Out:
# end

# %% [markdown]
# ### Plotting the validation results

# %%
l2_loss, img_inputs, img_prediction = get_validation_data(train_id, coll, 20)
plot_l2_loss(l2_loss, train_id)

np_inputs = np.array(img_inputs).transpose([0,2,3,4,1])
np_prediction = np.array(img_prediction).transpose([0,2,3,4,1])
my_shape = np_inputs.shape

# %%
def show_row(in_row, num_show = None):
    from matplotlib.pyplot import figure, imshow, axis
    from matplotlib.image import imread
    
    if num_show is None:
        num_show = len(in_row)
    fig = figure(figsize = [20, 6])
    for i in range(num_show):
        a = fig.add_subplot(1,num_show, i+1)
        a.get_xaxis().set_visible(False)
        a.get_yaxis().set_visible(False)
        imshow(in_row[:,:,:,i])

# %% [markdown]
# ##### Targets

# %%
show_row(np_inputs[-1,:].squeeze(), 10)

# %% [markdown]
# ##### Final step

# %%
show_row(np_prediction[-1,:].squeeze(), 10)

# %% [markdown]
# ## Part 2: Representational Similararity Analysis (RSA)

# %%
data, uni_steps, uni_var = get_neural_exp_data(coll, test_id)

# %%
for ivar in uni_var:
    for istep in uni_steps:
        if (ivar, istep) in data:
            print((ivar, istep))
# Out:
# (u'V0V3V6', 10000)
# (u'V0V3V6', 1000)
# (u'V6', 10000)
# (u'V6', 1000)

# %% [markdown]
# ### Analyzing the RDM results
#
# We will start with visualizing the RDMs we computed for each layer and the IT neurons.

# %%
for ivar in uni_var:
    for istep in uni_steps:
        if (ivar, istep) in data:
            plot_rdms(data[(ivar, istep)], vars(my_model_shallow)['layers'], istep)

# %% [markdown]
# ### Analyzing the categorization results
#
# Now let's visualize the results of the categorization and within categorization test we performed for each layer. Describe what you see.

# %%
for ivar in uni_var:
    for istep in uni_steps:
        if (ivar, istep) in data:
            print((ivar, istep))
            try:
                plot_categorization_results(data[(ivar, istep)], vars(my_model_shallow)['layers'], istep)
            except:
                pass
# Out:
# (u'V0V3V6', 10000)
# (u'V0V3V6', 1000)
# (u'V6', 10000)
# (u'V6', 1000)

# %%
for ivar in uni_var:
    for istep in uni_steps:
        print((ivar, istep))
        categories = ['Animals', 'Boats', 'Cars', 'Chairs', 'Faces', 'Fruits', 'Planes', 'Tables']
        for category in categories:
            try:
                plot_categorization_results(data[(ivar, istep)], vars(my_model_shallow)['layers'], istep, category=category)
            except:
                pass
# Out:
# (u'V0V3V6', 10000)
# (u'V0V3V6', 1000)
# (u'V6', 10000)
# (u'V6', 1000)
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %% [markdown]
# ### Continuous estimation results
# We regress our activations against the 'ty' continuous variable.

# %%
for ivar in uni_var:
    for istep in uni_steps:
        print((ivar, istep))
        print("Continuous Estimation Task for ty \n")
        for layer in vars(my_model_shallow)['layers']:
            print('layer:' + layer)
            my_key = 'continuous_' + layer
            if my_key in data[(ivar, istep)]:
                print(data[(ivar, istep)]['continuous_' + layer])
                print("")
# Out:
# (u'V0V3V6', 10000)
# Continuous Estimation Task for ty
#
# layer:conv1
# {u'corr_splitarray_loss': [0.6915390308159189, 0.6446114304480908, 0.6937197329541377, 0.670045616929541, 0.6857835816697845, 0.6604518593378936, 0.7810777183571291, 0.6416369179998753, 0.6405217763616033, 0.6042231067020858, 0.7363806542954963, 0.5956133920175826, 0.8235084552076113, 0.6892938323829324, 0.6475331032395988, 0.7329053099228486, 0.8001564769299476, 0.5968447889309725, 0.7006776515512255, 0.687165893959865], u'rsquared_loss_stderror': 0.04973903857314227, u'rsquared_splitarray_loss': [0.9227997888092628, 0.8744989091809448, 0.9135548287452494, 0.8916225328153333, 0.9185817127657716, 0.9310645434604635, 0.9642425781701014, 0.8783871078676886, 0.8756732846575028, 0.8472182664900264, 0.9595527868477085, 0.8608559720440898, 1.0183882377048306, 0.9164811821977108, 0.8786930472402038, 0.9897088969546465, 1.0063281961744437, 0.8487731959689948, 0.9528371091383969, 0.9435948480609274], u'corr_loss_stderror': 0.06203943058845232, u'rsquared_loss': 0.9196428512647149, u'corr_loss': 0.686184516500707}
985637772259305, 0.9965317367273236, 0.9745394417308191, 1.0837207478964186, 0.950895348220351, 0.9598549791714475, 1.013636793705519, 0.9680358316577176, 0.9167446670508725, 0.8996417362354107, 0.8367813529502438, 1.0725365885978282, 0.8199664948769056, 0.9459663670221788, 0.9687993144668723, 0.8376020698920212, 1.1229309503667733], u'corr_loss_stderror': 0.08218152319207549, u'rsquared_loss': 0.9643080876821046, u'corr_loss': 0.7028149934494332}
#
# layer:deconv1
# {u'corr_splitarray_loss': [0.6973852744854656, 0.7256266751103415, 0.8216667585698392, 0.6821100046993179, 0.636300222835317, 0.6362961966855998, 0.7499935917596561, 0.7647719256223803, 0.6714066834792944, 0.6545800413659613, 0.68902510272699, 0.7224347698178073, 0.6761195211256257, 0.6703067932736422, 0.6988354933264613, 0.5450019556440009, 0.7088774295772482, 0.6313817189399197, 0.636448750892172, 0.8333004694139989], u'rsquared_loss_stderror': 0.06688676280290344, u'rsquared_splitarray_loss': [0.9720907697112203, 0.967476397028503, 1.129485216569586, 0.9508612159517444, 0.9613106591776017, 0.9674768433786317, 1.042381121367612, 1.0471333449175007, 0.9362180135191308, 0.9338597579574932, 0.9848486321940366, 0.9668894017982482, 0.9655983087029408, 0.9386233603133065, 0.9743571152176963, 0.8236248437876502, 1.0563130768153, 0.889856766492967, 0.9206813275170236, 1.0773741091793507], u'corr_loss_stderror': 0.06522153171336022, u'rsquared_loss': 0.9753230140798772, u'corr_loss': 0.6925934689675519}

# %% [markdown]
# ## Part 3: Neural Response Regression
#
# We will now display the results of the regression test.

# %%
# TODO Fix this, get response from Damian
#plot_regression_results(data, target_layers, step)

#step = validation_data[-1]['step']

def plot_regression_results(data, target_layers, step):
    """
    Prints out the noise corrected multi rsquared loss for each layer.
    
    You will need to EDIT this function.
    """
    for layer in target_layers:
            k = 'it_regression_' + layer
            print(data.keys())
            if 'it_regression_conv1' in data:
                print(data['it_regression_conv1'])
            if k in data:
                print('step', step, 'layer', layer, 1 - data[k]['noise_corrected_multi_rsquared_loss'])

for ivar in uni_var:
    for istep in uni_steps:
        if (ivar, istep) in data:
            #print(data[(ivar, istep)].keys())
            plot_regression_results(data[(ivar, istep)], vars(my_model_shallow)['layers'], istep)
# Out:
# [u'continuous_deconv1', u'rdm_deconv1', u'spearman_corrcoef_conv1', u'within_categorization_deconv1', u'categorization_conv1', u'it_regression_conv1', u'conv1_kernel', u'continuous_conv1', u'spearman_corrcoef_deconv1', u'rdm_conv1', u'it_regression_deconv1', u'categorization_deconv1', u'rdm_it', u'within_categorization_conv1']
# {u'corr_splitarray_loss': [0.7994164714016785, 0.809049190063264, 0.8203168570752776, 0.7936419900948118, 0.7928681864164726], u'noise_corrected_multi_rsquared_array_loss': [0.89476733370391, 0.8789638109793338, 0.9460491517918113, 0.9015302507646883, 0.9272825563037184, 0.981390585051926, 0.9742920288555721, 0.9379860312899672, 0.9695693530004037, 0.971307957675215, 0.9711861597630437, 0.9494648720146524, 0.9946
.0258214795158394, 0.987811820160567, 0.6719230555596317, 0.8889433887658162, 0.8564501141011972, 0.975581394840666, 0.8852489562212131, 0.9044985126910859, 0.9738256920214029, 0.8297676627264481, 0.45436861568977893, 0.9664374973191767, 0.7067916906241746, 0.9763926221720858, 0.1821231141977111, 0.8321659064749511, 0.9025805528544236, 0.6934946597768105, 0.8762988683830937, 0.9616195243214853, 0.6755796247750158, 0.9614020919647173, 0.9681700149857294, 0.8102703065022588, 0.8334893236155354, 0.9471729528792938, 0.9639888729911099, 0.9233492861180306, 0.8589946050850514, 0.6843772224721918, 0.6204602560364514, 0.9424246420712166, 0.9898999901054877, 0.9518333729048833, 0.9926757925752663, 0.966905626866885, 0.9921126857961152, 0.9637638573890588, 0.9518334927399623, 0.9889588683054443, 0.9786207363373147, 0.9584444148136454, 0.981929884124088, 0.9791309854879338, 0.8088234121251654, 0.9682380166665265, 0.7210058261793997, 0.6789166617972656, 0.9005534269800359, 0.8043017334693043, 0.9171241175265399, 0.7538007443625607, 0.863450661356409, 0.837172441762821, 0.8313488114811582, 0.973412211767668, 0.7299429496420702], u'noise_corrected_multi_rsquared_loss_stderror': 0.008886060212600196, u'noise_corrected_multi_rsquared_array_loss_stderror': [0.02909134930587835, 0.024755646117135762, 0.013475311240262475, 0.005330655773525456, 0.019661645292787754, 0.0030691075847232366, 0.03347118589013878, 0.028560537340263776, 0.03802558654826371, 0.019382455463952227, 0.01428815386045873, 0.03018471276383704, 0.02271709184342711, 0.03841554342303641, 0.02321454645727777, 0.028761534033850088, 0.0290892930516 ...
# ('step', 1000, 'layer', 'deconv1', 0.04458910432983543)
# [u'continuous_deconv1', u'rdm_deconv1', u'spearman_corrcoef_conv1', u'within_categorization_deconv1', u'categorization_conv1', u'it_regression_conv1', u'conv1_kernel', u'continuous_conv1', u'spearman_corrcoef_deconv1', u'rdm_conv1', u'it_regression_deconv1', u'categorization_deconv1', u'rdm_it', u'within_categorization_conv1']
# nan
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-e3b7dae0bf9c> in <module>()
#      22         if (ivar, istep) in data:
#      23             #print(data[(ivar, istep)].keys())
# ---> 24             plot_regression_results(data[(ivar, istep)], vars(my_model_shallow)['layers'], istep)
#
# <ipython-input-20-e3b7dae0bf9c> in plot_regression_results(data, target_layers, step)
#      16                 print(data['it_regression_conv1'])
#      17             if k in data:
# ---> 18                 print('step', step, 'layer', layer, 1 - data[k]['noise_corrected_multi_rsquared_loss'])
#      19
#      20 for ivar in uni_var:
#
# TypeError: 'float' object has no attribute '__getitem__'

# %% [markdown]
# ## Part 4: Filter Visualization Evaluations
#
# Lastly, we will plot the conv1 filter kernels.

# %%
for ivar in uni_var:
    for istep in uni_steps:
        print((ivar, istep))
        plot_conv1_kernels(data[(ivar, istep)])
# Out:
# (u'V0V3V6', 10000)
# (u'V0V3V6', 1000)
# (u'V6', 10000)
# (u'V6', 1000)

# %% [markdown]
# ## Part 5: Evaluation of the unsupervised models on ImageNet

# %%
# linear_classification(data)
